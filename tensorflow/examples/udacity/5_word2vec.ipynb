# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  f = zipfile.ZipFile(filename)
  for name in f.namelist():
    return tf.compat.as_str(f.read(name)).split()
  f.close()
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %%
words
# Out:
# ['anarchism',
#  'originated',
#  'as',
#  'a',
#  'term',
#  'of',
#  'abuse',
#  'first',
#  'used',
#  'against',
#  'early',
#  'working',
#  'class',
#  'radicals',
#  'including',
#  'the',
#  'diggers',
#  'of',
#  'the',
#  'english',
#  'revolution',
#  'and',
#  'the',
#  'sans',
#  'culottes',
#  'of',
#  'the',
#  'french',
#  'revolution',
#  'whilst',
#  'the',
#  'term',
#  'is',
#  'still',
#  'used',
#  'in',
#  'a',
#  'pejorative',
#  'way',
#  'to',
#  'describe',
#  'any',
#  'act',
#  'that',
#  'used',
#  'violent',
#  'means',
#  'to',
#  'destroy',
#  'the',
#  'organization',
#  'of',
#  'society',
#  'it',
#  'has',
#  'also',
#  'been',
#  'taken',
#  'up',
#  'as',
#  'a',
#  'positive',
#  'label',
#  'by',
#  'self',
#  'defined',
#  'anarchists',
#  'the',
#  'word',
#  'anarchism',
#  'is',
#  'derived',
#  'from',
#  'the',
#  'greek',
#  'without',
#  'archons',
#  'ruler',
#  'chief',
#  'king',
#  'anarchism',
#  'as',
#  'a',
#  'political',
#  'philosophy',
#  'is',
#  'the',
#  'belief',
#  'that',
#  'rulers',
#  'are',
#  'unnecessary',
#  'and',
#  'should',
#  'be',
#  'abolished',
#  'although',
#  'there',
#  'are',
#  'differing',
#  'interpretations',
#  'of',
#  'what',
#  'this',
#  'means',
#  'anarchism',
#  'also',
#  'refers',
#  'to',
#  'related',
#  'social',
#  'movements',
#  'that',
#  'advocate',
#  'the',
#  'elimination',
#  'of',
#  'authoritarian',
#  'institutions',
#  'particularly',
#  'the',
#  'state',
#  'the',
#  'word',
#  'anarchy',
#  'as',
#  'most',
#  'anarchists',
#  'use',
#  'it',
#  'does',
#  'not',
#  'imply',
#  'chaos',
#  'nihilism',
#  'or',
#  'anomie',
#  'but',
#  'rather',
#  'a',
#  'harmonious',
#  'anti',
#  'authoritarian',
#  'society',
#  'in',
#  'place',
#  'of',
#  'what',
#  'are',
#  'regarded',
#  'as',
#  'authoritarian',
#  'political',
#  'structures',
#  'and',
#  'coercive',
#  'economic',
#  'institutions',
#  'anarchists',
#  'advocate',
#  'social',
#  'relations',
#  'based',
#  'upon',
#  'voluntary',
#  'association',
#  'of',
#  'autonomous',
#  'individuals',
#  'mutual',
#  'aid',
#  'and',
#  'self',
#  'governance',
#  'while',
#  'anarchism',
#  'is',
#  'most',
#  'easily',
#  'defined',
#  'by',
#  'what',
#  'it',
#  'is',
#  'against',
#  'anarchists',
#  'also',
#  'offer',
#  'positive',
#  'visions',
#  'of',
#  'what',
#  'they',
#  'believe',
#  'to',
#  'be',
#  'a',
#  'truly',
#  'free',
#  'society',
#  'however',
#  'ideas',
#  'about',
#  'how',
#  'an',
#  'anarchist',
#  'society',
#  'might',
#  'work',
#  'vary',
#  'considerably',
#  'especially',
#  'with',
#  'respect',
#  'to',
#  'economics',
#  'there',
#  'is',
#  'also',
#  'disagreement',
#  'about',
#  'how',
#  'a',
#  'free',
#  'society',
#  'might',
#  'be',
#  'brought',
#  'about',
#  'origins',
#  'and',
#  'predecessors',
#  'kropotkin',
#  'and',
#  'others',
#  'argue',
#  'that',
#  'before',
#  'recorded',
#  'history',
#  'human',
#  'society',
#  'was',
#  'organized',
#  'on',
#  'anarchist',
#  'principles',
#  'most',
#  'anthropologists',
#  'follow',
#  'kropotkin',
#  'and',
#  'engels',
#  'in',
#  'believing',
#  'that',
#  'hunter',
#  'gatherer',
#  'bands',
#  'were',
#  'egalitarian',
#  'and',
#  'lacked',
#  'division',
#  'of',
#  'labour',
#  'accumulated',
#  'wealth',
#  'or',
#  'decreed',
#  'law',
#  'and',
#  'had',
#  'equal',
#  'access',
#  'to',
#  'resources',
#  'william',
#  'godwin',
#  'anarchists',
#  'including',
#  'the',
#  'the',
#  'anarchy',
#  'organisation',
#  'and',
#  'rothbard',
#  'find',
#  'anarchist',
#  'attitudes',
#  'in',
#  'taoism',
#  'from',
#  'ancient',
#  'china',
#  'kropotkin',
#  'found',
#  'similar',
#  'ideas',
#  'in',
#  'stoic',
#  'zeno',
#  'of',
#  'citium',
#  'according',
#  'to',
#  'kropotkin',
#  'zeno',
#  'repudiated',
#  'the',
#  'omnipotence',
#  'of',
#  'the',
#  'state',
#  'its',
#  'intervention',
#  'and',
#  'regimentation',
#  'and',
#  'proclaimed',
#  'the',
#  'sovereignty',
#  'of',
#  'the',
#  'moral',
#  'law',
#  'of',
#  'the',
#  'individual',
#  'the',
#  'anabaptists',
#  'of',
#  'one',
#  'six',
#  'th',
#  'century',
#  'europe',
#  'are',
#  'sometimes',
#  'considered',
#  'to',
#  'be',
#  'religious',
#  'forerunners',
#  'of',
#  'modern',
#  'anarchism',
#  'bertrand',
#  'russell',
#  'in',
#  'his',
#  'history',
#  'of',
#  'western',
#  'philosophy',
#  'writes',
#  'that',
#  'the',
#  'anabaptists',
#  'repudiated',
#  'all',
#  'law',
#  'since',
#  'they',
#  'held',
#  'that',
#  'the',
#  'good',
#  'man',
#  'will',
#  'be',
#  'guided',
#  'at',
#  'every',
#  'moment',
#  'by',
#  'the',
#  'holy',
#  'spirit',
#  'from',
#  'this',
#  'premise',
#  'they',
#  'arrive',
#  'at',
#  'communism',
#  'the',
#  'diggers',
#  'or',
#  'true',
#  'levellers',
#  'were',
#  'an',
#  'early',
#  'communistic',
#  'movement',
#  'during',
#  'the',
#  'time',
#  'of',
#  'the',
#  'english',
#  'civil',
#  'war',
#  'and',
#  'are',
#  'considered',
#  'by',
#  'some',
#  'as',
#  'forerunners',
#  'of',
#  'modern',
#  'anarchism',
#  'in',
#  'the',
#  'modern',
#  'era',
#  'the',
#  'first',
#  'to',
#  'use',
#  'the',
#  'term',
#  'to',
#  'mean',
#  'something',
#  'other',
#  'than',
#  'chaos',
#  'was',
#  'louis',
#  'armand',
#  'baron',
#  'de',
#  'lahontan',
#  'in',
#  'his',
#  'nouveaux',
#  'voyages',
#  'dans',
#  'l',
#  'am',
#  'rique',
#  'septentrionale',
#  'one',
#  'seven',
#  'zero',
#  'three',
#  'where',
#  'he',
#  'described',
#  'the',
#  'indigenous',
#  'american',
#  'society',
#  'which',
#  'had',
#  'no',
#  'state',
#  'laws',
#  'prisons',
#  'priests',
#  'or',
#  'private',
#  'property',
#  'as',
#  'being',
#  'in',
#  'anarchy',
#  'russell',
#  'means',
#  'a',
#  'libertarian',
#  'and',
#  'leader',
#  'in',
#  'the',
#  'american',
#  'indian',
#  'movement',
#  'has',
#  'repeatedly',
#  'stated',
#  'that',
#  'he',
#  'is',
#  'an',
#  'anarchist',
#  'and',
#  'so',
#  'are',
#  'all',
#  'his',
#  'ancestors',
#  'in',
#  'one',
#  'seven',
#  'nine',
#  'three',
#  'in',
#  'the',
#  'thick',
#  'of',
#  'the',
#  'french',
#  'revolution',
#  'william',
#  'godwin',
#  'published',
#  'an',
#  'enquiry',
#  'concerning',
#  'political',
#  'justice',
#  'although',
#  'godwin',
#  'did',
#  'not',
#  'use',
#  'the',
#  'word',
#  'anarchism',
#  'many',
#  'later',
#  'anarchists',
#  'have',
#  'regarded',
#  'this',
#  'book',
#  'as',
#  'the',
#  'first',
#  'major',
#  'anarchist',
#  'text',
#  'and',
#  'godwin',
#  'as',
#  'the',
#  'founder',
#  'of',
#  'philosophical',
#  'anarchism',
#  'but',
#  'at',
#  'this',
#  'point',
#  'no',
#  'anarchist',
#  'movement',
#  'yet',
#  'existed',
#  'and',
#  'the',
#  'term',
#  'anarchiste',
#  'was',
#  'known',
#  'mainly',
#  'as',
#  'an',
#  'insult',
#  'hurled',
#  'by',
#  'the',
#  'bourgeois',
#  'girondins',
#  'at',
#  'more',
#  'radical',
#  'elements',
#  'in',
#  'the',
#  'french',
#  'revolution',
#  'the',
#  'first',
#  'self',
#  'labelled',
#  'anarchist',
#  'pierre',
#  'joseph',
#  'proudhon',
#  'it',
#  'is',
#  'commonly',
#  'held',
#  'that',
#  'it',
#  'wasn',
#  't',
#  'until',
#  'pierre',
#  'joseph',
#  'proudhon',
#  'published',
#  'what',
#  'is',
#  'property',
#  'in',
#  'one',
#  'eight',
#  'four',
#  'zero',
#  'that',
#  'the',
#  'term',
#  'anarchist',
#  'was',
#  'adopted',
#  'as',
#  'a',
#  'self',
#  'description',
#  'it',
#  'is',
#  'for',
#  'this',
#  'reason',
#  'that',
#  'some',
#  'claim',
#  'proudhon',
#  'as',
#  'the',
#  'founder',
#  'of',
#  'modern',
#  'anarchist',
#  'theory',
#  'in',
#  'what',
#  'is',
#  'property',
#  'proudhon',
#  'answers',
#  'with',
#  'the',
#  'famous',
#  'accusation',
#  'property',
#  'is',
#  'theft',
#  'in',
#  'this',
#  'work',
#  'he',
#  'opposed',
#  'the',
#  'institution',
#  'of',
#  'decreed',
#  'property',
#  'propri',
#  't',
#  'where',
#  'owners',
#  'have',
#  'complete',
#  'rights',
#  'to',
#  'use',
#  'and',
#  'abuse',
#  'their',
#  'property',
#  'as',
#  'they',
#  'wish',
#  'such',
#  'as',
#  'exploiting',
#  'workers',
#  'for',
#  'profit',
#  'in',
#  'its',
#  'place',
#  'proudhon',
#  'supported',
#  'what',
#  'he',
#  'called',
#  'possession',
#  'individuals',
#  'can',
#  'have',
#  'limited',
#  'rights',
#  'to',
#  'use',
#  'resources',
#  'capital',
#  'and',
#  'goods',
#  'in',
#  'accordance',
#  'with',
#  'principles',
#  'of',
#  'equality',
#  'and',
#  'justice',
#  'proudhon',
#  's',
#  'vision',
#  'of',
#  'anarchy',
#  'which',
#  'he',
#  'called',
#  'mutualism',
#  'mutuellisme',
#  'involved',
#  'an',
#  'exchange',
#  'economy',
#  'where',
#  'individuals',
#  'and',
#  'groups',
#  'could',
#  'trade',
#  'the',
#  'products',
#  'of',
#  'their',
#  'labor',
#  'using',
#  'labor',
#  'notes',
#  'which',
#  'represented',
#  'the',
#  'amount',
#  'of',
#  'working',
#  'time',
#  'involved',
#  'in',
#  'production',
#  'this',
#  'would',
#  'ensure',
#  'that',
#  'no',
#  'one',
#  'would',
#  'profit',
#  'from',
#  'the',
#  'labor',
#  'of',
#  'others',
#  'workers',
#  'could',
#  'freely',
#  'join',
#  'together',
#  'in',
#  'co',
#  'operative',
#  'workshops',
#  'an',
#  'interest',
#  'free',
#  'bank',
#  'would',
#  'be',
#  'set',
#  'up',
#  'to',
#  'provide',
#  'everyone',
#  'with',
#  'access',
#  'to',
#  'the',
#  'means',
#  'of',
#  'production',
#  'proudhon',
#  's',
#  'ideas',
#  'were',
#  'influential',
#  'within',
#  'french',
#  'working',
#  'class',
#  'movements',
#  'and',
#  'his',
#  'followers',
#  'were',
#  'active',
#  'in',
#  'the',
#  'revolution',
#  'of',
#  'one',
#  'eight',
#  'four',
#  'eight',
#  'in',
#  'france',
#  'proudhon',
#  's',
#  'philosophy',
#  'of',
#  'property',
#  'is',
#  'complex',
#  'it',
#  'was',
#  'developed',
#  'in',
#  'a',
#  'number',
#  'of',
#  'works',
#  'over',
#  'his',
#  'lifetime',
#  'and',
#  'there',
#  'are',
#  'differing',
#  'interpretations',
#  'of',
#  'some',
#  'of',
#  'his',
#  'ideas',
#  'for',
#  'more',
#  'detailed',
#  'discussion',
#  'see',
#  'here',
#  'max',
#  'stirner',
#  's',
#  'egoism',
#  'in',
#  'his',
#  'the',
#  'ego',
#  'and',
#  'its',
#  'own',
#  'stirner',
#  'argued',
#  'that',
#  'most',
#  'commonly',
#  'accepted',
#  'social',
#  'institutions',
#  'including',
#  'the',
#  'notion',
#  'of',
#  'state',
#  'property',
#  'as',
#  'a',
#  'right',
#  'natural',
#  'rights',
#  'in',
#  'general',
#  'and',
#  'the',
#  'very',
#  'notion',
#  'of',
#  'society',
#  'were',
#  'mere',
#  'illusions',
#  'or',
#  'ghosts',
#  'in',
#  'the',
#  'mind',
#  'saying',
#  'of',
#  'society',
#  'that',
#  'the',
#  'individuals',
#  'are',
#  'its',
#  'reality',
#  'he',
#  'advocated',
#  'egoism',
#  'and',
#  'a',
#  'form',
#  'of',
#  'amoralism',
#  'in',
#  'which',
#  'individuals',
#  'would',
#  'unite',
#  'in',
#  'associations',
#  'of',
#  'egoists',
#  'only',
#  'when',
#  'it',
#  'was',
#  'in',
#  'their',
#  'self',
#  'interest',
#  'to',
#  'do',
#  'so',
#  'for',
#  'him',
#  'property',
#  'simply',
#  'comes',
#  'about',
#  'through',
#  'might',
#  'whoever',
#  'knows',
#  'how',
#  'to',
#  'take',
#  'to',
#  'defend',
#  'the',
#  'thing',
#  'to',
#  'him',
#  'belongs',
#  'property',
#  'and',
#  'what',
#  'i',
#  'have',
#  'in',
#  'my',
#  'power',
#  'that',
#  'is',
#  'my',
#  'own',
#  'so',
#  'long',
#  'as',
#  'i',
#  'assert',
#  'myself',
#  'as',
#  'holder',
#  'i',
#  'am',
#  'the',
#  'proprietor',
#  'of',
#  'the',
#  'thing',
#  'stirner',
#  'never',
#  'called',
#  'himself',
#  'an',
#  'anarchist',
#  'he',
#  'accepted',
#  'only',
#  'the',
#  'label',
#  'egoist',
#  'nevertheless',
#  'his',
#  'ideas',
#  'were',
#  'influential',
#  'on',
#  'many',
#  'individualistically',
#  'inclined',
#  'anarchists',
#  'although',
#  'interpretations',
#  'of',
#  'his',
#  'thought',
#  'are',
#  'diverse',
#  ...]

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window   # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'a', 'originated', 'term', 'as', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['term', 'originated', 'a', 'anarchism', 'as', 'term', 'of', 'originated']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in xrange(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in xrange(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.401240
# Nearest to b: constructs, greenfacts, niv, innocent, dutt, fenrir, strengthen, harpers,
# Nearest to also: classical, hummel, openstep, drifted, royale, detectable, intruding, redemptive,
# Nearest to used: rashi, reductase, xiang, defect, flavor, catcher, delegated, informer,
# Nearest to and: cotswolds, stalin, eventually, grenville, wcl, duchamp, optical, asleep,
# Nearest to system: sushi, kor, healy, clinker, danville, apec, lego, prosecute,
# Nearest to state: vliw, poets, satyr, garden, raison, sync, motherboards, marsupials,
# Nearest to there: andersen, alongside, vico, keane, sedan, neuropsychological, nightmarish, distortions,
# Nearest to has: chih, pell, americans, allocation, fairer, intramolecular, polybius, juries,
# Nearest to be: debra, drained, courted, confederal, suicidal, displayed, cyclops, tacit,
# Nearest to their: aerodynamics, crowned, profoundly, weasel, abhorred, adrenaline, gainsborough, jerusalem,
# Nearest to two: reuven, purana, mw, denoting, domitius, cynical, poincar, boil,
# Nearest to over: korea, tipping, unpopular, acronym, unnatural, led, epidemics, fon,
# Nearest to were: alga, accelerating, stake, mhz, rhodope, hyperbole, lumbar, furtherance,
# Nearest to can: elf, cultural, reload, hudsucker, electricity, kuiper, priming, apocryphal,
# Nearest to other: heritability, hanging, orl, je, leena, haznawi, ordnance, technical,
# Nearest to about: timberlake, romani, jeep, pentagram, orators, ambulatory, foul, jourdan,
# Average loss at step 2000: 4.359584
# Average loss at step 4000: 3.862961
# Average loss at step 6000: 3.783825
# Average loss at step 8000: 3.686032
# Average loss at step 10000: 3.617804
# Nearest to b: d, constructs, fenrir, bonhomme, greenfacts, pendragon, niv, innocent,
# Nearest to also: sometimes, intruding, mostly, which, usually, still, hummel, roux,
# Nearest to used: defect, admission, hilltop, shown, groningen, xiang, galactose, strategies,
# Nearest to and: or, s, lv, filming, wcl, but, steno, of,
# Nearest to system: healy, danville, lego, legitimized, prosecute, sushi, lags, thc,
# Nearest to state: minbari, cernunnos, vliw, garden, vassals, sinned, satyr, slabs,
# Nearest to there: it, they, which, cancer, taverns, ba, dialectal, often,
# Nearest to has: had, is, was, chih, have, nowy, consecrate, polybius,
# Nearest to be: have, by, flocks, is, been, clodius, was, gordie,
# Nearest to their: his, expectancy, its, the, feared, profoundly, big, landmass,
# Nearest to two: five, three, four, six, seven, eight, nine, one,
# Nearest to over: korea, kano, ep, conformations, reformed, led, east, demonstrations,
# Nearest to were: are, have, was, had, apc, agreed, accelerating, guangzhou,
# Nearest to can: would, will, could, should, may, nye, electricity, nuanced,
# Nearest to other: all, haznawi, sedation, technical, leena, ev, collage, differentiation,
# Nearest to about: orators, living, menai, jeep, osu, trilemma, cabell, timberlake,
# Average loss at step 12000: 3.603123
# Average loss at step 14000: 3.570795
# Average loss at step 16000: 3.407178
# Average loss at step 18000: 3.457726
# Average loss at step 20000: 3.541207
# Nearest to b: d, constructs, fenrir, gegen, french, johnson, taming, africans,
# Nearest to also: now, which, sometimes, usually, still, mostly, who, intruding,
# Nearest to used: groningen, noted, incommunicado, done, rebounding, hilltop, admission, defect,
# Nearest to and: or, but, while, which, in, hyi, ulcers, partnered,
# Nearest to system: healy, danville, lego, law, cowpox, legitimized, lags, quartets,
# Nearest to state: minbari, cernunnos, vliw, relevant, worried, metal, tenzin, satyr,
# Nearest to there: it, they, which, he, anarchists, often, who, competency,
# Nearest to has: had, was, have, is, allocation, consecrate, chih, preseason,
# Nearest to be: have, was, by, been, is, gordie, flocks, were,
# Nearest to their: his, its, the, expectancy, her, alertness, landmass, faroes,
# Nearest to two: three, five, six, four, one, seven, eight, zero,
# Nearest to over: eamonn, korea, fon, khattab, reformed, led, interviewer, kano,
# Nearest to were: are, was, had, have, is, rnir, be, affidavit,
# Nearest to can: would, may, could, will, should, must, might, nuanced,
# Nearest to other: many, all, inspirational, are, these, intv, garrison, sedation,
# Nearest to about: orators, osu, menai, trilemma, destructive, cabell, nic, plaintext,
# Average loss at step 22000: 3.503766
# Average loss at step 24000: 3.489099
# Average loss at step 26000: 3.475449
# Average loss at step 28000: 3.483355
# Average loss at step 30000: 3.501666
# Nearest to b: d, rocked, wooden, constructs, taming, caffeine, trimming, nabba,
# Nearest to also: now, sometimes, actually, often, usually, still, kirlian, which,
# Nearest to used: known, noted, available, seen, done, shown, unsolicited, groningen,
# Nearest to and: or, wcl, but, partnered, american, fury, numeral, while,
# Nearest to system: healy, lego, danville, ricardian, systems, rife, cowpox, jung,
# Nearest to state: relevant, minbari, tenzin, territory, novella, cernunnos, arab, abject,
# Nearest to there: they, it, he, which, often, uncertain, still, no,
# Nearest to has: had, have, is, was, allocation, having, mobster, consecrate,
# Nearest to be: been, have, is, refer, are, were, flocks, was,
# Nearest to their: his, its, her, the, these, nieces, faroes, expectancy,
# Nearest to two: four, three, six, five, one, seven, eight, nine,
# Nearest to over: eamonn, korea, led, kano, fon, interviewer, reformed, dynasties,
# Nearest to were: are, was, have, had, been, agreed, rnir, be,
# Nearest to can: would, may, could, will, must, should, might, cannot,
# Nearest to other: inspirational, these, many, are, some, several, bentsen, garrison,
# Nearest to about: osu, orators, destructive, drinkordie, menai, trilemma, osamu, cabell,
# Average loss at step 32000: 3.502255
# Average loss at step 34000: 3.495981
# Average loss at step 36000: 3.450312
# Average loss at step 38000: 3.303319
# Average loss at step 40000: 3.432076
# Nearest to b: d, UNK, c, rocked, hadrons, taming, sds, young,
# Nearest to also: usually, often, now, sometimes, generally, which, still, actually,
# Nearest to used: known, available, seen, found, referred, noted, done, written,
# Nearest to and: or, but, like, envisaged, in, vauban, bonzos, sibm,
# Nearest to system: systems, healy, danville, ricardian, lego, rife, jung, smoot,
# Nearest to state: relevant, territory, novella, tenzin, worried, minbari, arab, states,
# Nearest to there: they, it, he, which, often, she, still, uncertain,
# Nearest to has: had, have, was, is, consecrate, mobster, chih, defended,
# Nearest to be: have, been, flocks, were, was, are, is, become,
# Nearest to their: its, his, her, the, them, these, pdas, expectancy,
# Nearest to two: four, three, seven, six, five, eight, one, zero,
# Nearest to over: eamonn, jurisdictional, resist, aids, dynasties, fon, reformed, clos,
# Nearest to were: are, have, had, was, these, been, be, while,
# Nearest to can: may, will, could, would, must, should, might, cannot,
# Nearest to other: different, some, several, these, many, yorkist, more, influential,
# Nearest to about: destructive, orators, osu, reshaping, trilemma, cabell, representational, kiribati,
# Average loss at step 42000: 3.428133
# Average loss at step 44000: 3.458045
# Average loss at step 46000: 3.449389
# Average loss at step 48000: 3.354588
# Average loss at step 50000: 3.383243
# Nearest to b: d, c, h, r, e, f, rocked, n,
# Nearest to also: now, which, often, usually, sometimes, still, generally, typically,
# Nearest to used: known, referred, seen, written, available, described, considered, found,
# Nearest to and: or, including, but, while, however, filming, wcl, prosecutor,
# Nearest to system: systems, healy, danville, rife, ricardian, base, ttl, smoot,
# Nearest to state: relevant, novella, adenauer, territory, neutronic, worried, tenzin, ceasing,
# Nearest to there: they, it, he, she, who, still, uncertain, now,
# Nearest to has: had, have, is, was, poseidon, consecrate, having, trimming,
# Nearest to be: have, been, refer, being, was, become, were, produce,
# Nearest to their: its, his, her, the, your, pdas, them, both,
# Nearest to two: three, four, six, one, five, eight, zero, seven,
# Nearest to over: eamonn, jurisdictional, resist, about, doppler, flammable, oy, charlottenburg,
# Nearest to were: are, was, have, these, be, been, had, is,
# Nearest to can: may, could, would, will, must, should, might, cannot,
# Nearest to other: different, many, these, various, some, histones, several, materialism,
# Nearest to about: osu, orators, destructive, educated, armenian, over, gresham, invites,
# Average loss at step 52000: 3.435308
# Average loss at step 54000: 3.426664
# Average loss at step 56000: 3.440189
# Average loss at step 58000: 3.394691
# Average loss at step 60000: 3.391063
# Nearest to b: d, c, f, m, n, strunk, h, r,
# Nearest to also: now, often, still, usually, sometimes, typically, generally, which,
# Nearest to used: referred, known, written, seen, considered, described, available, vertebrate,
# Nearest to and: or, but, than, while, including, however, northwards, although,
# Nearest to system: systems, danville, base, healy, ricardian, route, rife, smoot,
# Nearest to state: relevant, territory, adenauer, city, neutronic, council, consists, result,
# Nearest to there: it, they, he, this, she, still, sometimes, which,
# Nearest to has: had, have, having, is, was, poseidon, consecrate, circular,
# Nearest to be: been, being, have, refer, produce, become, was, were,
# Nearest to their: its, his, her, the, our, your, my, pdas,
# Nearest to two: three, four, six, five, one, seven, eight, zero,
# Nearest to over: eamonn, into, through, about, resist, jurisdictional, idriss, regarding,
# Nearest to were: are, have, was, had, although, including, been, be,
# Nearest to can: may, could, would, will, must, should, might, cannot,
# Nearest to other: different, various, more, histones, many, several, these, some,
# Nearest to about: invites, destructive, armenian, osu, regarding, over, orators, disinterested,
# Average loss at step 62000: 3.233756
# Average loss at step 64000: 3.254424
# Average loss at step 66000: 3.407206
# Average loss at step 68000: 3.392554
# Average loss at step 70000: 3.364944
# Nearest to b: d, r, f, h, n, strunk, m, k,
# Nearest to also: now, often, still, sometimes, usually, which, typically, actually,
# Nearest to used: referred, known, seen, available, described, found, written, considered,
# Nearest to and: or, while, but, which, like, than, nerva, of,
# Nearest to system: systems, danville, healy, route, base, rife, powell, ricardian,
# Nearest to state: relevant, city, territory, adenauer, council, village, states, recherche,
# Nearest to there: they, it, he, she, sometimes, we, still, often,
# Nearest to has: had, have, is, was, having, consecrate, includes, poseidon,
# Nearest to be: been, is, were, become, being, have, refer, easily,
# Nearest to their: its, his, her, the, our, your, some, my,
# Nearest to two: three, four, six, seven, one, five, eight, zero,
# Nearest to over: eamonn, about, resist, bogside, doppler, numan, around, charlottenburg,
# Nearest to were: are, have, was, be, had, been, agreed, including,
# Nearest to can: may, could, would, will, must, should, might, cannot,
# Nearest to other: different, various, sloping, others, many, religious, economies, earnings,
# Nearest to about: invites, over, regarding, approximately, osu, armenian, gresham, disinterested,
# Average loss at step 72000: 3.374220
# Average loss at step 74000: 3.349937
# Average loss at step 76000: 3.308017
# Average loss at step 78000: 3.356406
# Average loss at step 80000: 3.380086
# Nearest to b: d, c, r, m, n, strunk, h, lars,
# Nearest to also: now, which, often, sometimes, typically, still, actually, never,
# Nearest to used: referred, known, available, seen, described, written, found, needed,
# Nearest to and: or, including, nicolas, while, but, citigroup, however, decimals,
# Nearest to system: systems, healy, danville, route, model, powell, ricardian, unit,
# Nearest to state: relevant, city, territory, adenauer, states, government, memetic, council,
# Nearest to there: it, they, he, she, sometimes, still, generally, we,
# Nearest to has: had, is, have, was, having, includes, consecrate, since,
# Nearest to be: been, being, have, become, refer, was, easily, are,
# Nearest to their: its, his, her, our, your, my, several, these,
# Nearest to two: three, six, four, seven, five, one, eight, zero,
# Nearest to over: eamonn, between, resist, around, into, about, doppler, bogside,
# Nearest to were: are, was, had, have, agreed, became, been, those,
# Nearest to can: could, may, will, must, would, should, might, cannot,
# Nearest to other: various, others, different, many, adl, infect, sloping, yorkist,
# Nearest to about: approximately, osu, invites, over, orators, disinterested, regarding, destructive,
# Average loss at step 82000: 3.405701
# Average loss at step 84000: 3.412918
# Average loss at step 86000: 3.389187
# Average loss at step 88000: 3.352783
# Average loss at step 90000: 3.361404
# Nearest to b: d, c, n, strunk, r, f, m, h,
# Nearest to also: now, often, actually, which, never, still, sometimes, typically,
# Nearest to used: referred, known, described, seen, called, available, needed, noted,
# Nearest to and: or, but, while, including, however, bested, in, by,
# Nearest to system: systems, model, route, healy, game, smoot, mesozoic, unit,
# Nearest to state: relevant, city, government, territory, states, adenauer, giulio, council,
# Nearest to there: they, it, she, he, generally, we, still, now,
# Nearest to has: had, have, is, was, includes, having, since, consecrate,
# Nearest to be: been, become, was, refer, being, have, produce, is,
# Nearest to their: its, his, her, your, our, the, my, dehydrated,
# Nearest to two: three, five, six, four, eight, seven, one, zero,
# Nearest to over: eamonn, within, against, about, around, off, between, fon,
# Nearest to were: are, was, had, agreed, while, have, these, is,
# Nearest to can: may, could, must, will, would, should, might, cannot,
# Nearest to other: various, different, histones, others, economies, religious, including, individual,
# Nearest to about: osu, regarding, over, armenian, disinterested, invites, orators, approximately,
# Average loss at step 92000: 3.396877
# Average loss at step 94000: 3.255690
# Average loss at step 96000: 3.358925
# Average loss at step 98000: 3.241182
# Average loss at step 100000: 3.356426
# Nearest to b: d, ivan, c, strunk, rocked, networked, wooden, envoy,
# Nearest to also: now, still, actually, sometimes, never, typically, often, usually,
# Nearest to used: referred, available, described, known, written, seen, needed, found,
# Nearest to and: or, but, while, although, who, including, when, like,
# Nearest to system: systems, model, healy, danville, unit, cmos, program, ricardian,
# Nearest to state: city, relevant, adenauer, states, territory, supercharged, government, giulio,
# Nearest to there: they, he, it, now, generally, she, still, we,
# Nearest to has: had, have, was, is, includes, having, consecrate, since,
# Nearest to be: been, refer, have, become, being, produce, are, easily,
# Nearest to their: its, his, her, your, our, the, several, my,
# Nearest to two: four, three, six, five, one, eight, seven, zero,
# Nearest to over: eamonn, within, around, resist, oy, off, about, between,
# Nearest to were: are, was, have, chevalier, these, had, although, including,
# Nearest to can: may, could, will, must, would, should, might, cannot,
# Nearest to other: others, various, including, different, histones, economies, earnings, moh,
# Nearest to about: approximately, regarding, donaghy, worse, around, over, orators, disinterested,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(np.asfarray(final_embeddings[1:num_points+1, :], dtype='float' ))

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to Word2Vec is called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %% [markdown]
# TODO:
# - Switch labels and input
# - Add intermediate step in training to sum the input vectors (hidden unit) per label
# - Adapt the matrix dimensionalities

# %%
data_index = 0

def generate_batch_cbow(batch_size, skip_window):
  global data_index
  outcome_size = batch_size - 2 * skip_window
  batch = np.ndarray(shape=(outcome_size, skip_window*2), dtype=np.int32)
  labels = np.ndarray(shape=(outcome_size, 1), dtype=np.int32)
  buffer = collections.deque(maxlen=batch_size)
  for _ in range(batch_size):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(outcome_size):
    target = i + skip_window
    labels[i, 0] = buffer[target] # target label at the center of the buffer
    for j in range(skip_window):
        batch[i, j] = buffer[target-(j + 1)]
        batch[i, j + skip_window] = buffer[target + (j+1)]
  buffer.append(data[data_index])
  data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for skip_window in [1, 2]:
    data_index = 0
    batch, labels = generate_batch_cbow(batch_size=8, skip_window=skip_window)
    print('\nwith skip_window = %d:' % (skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch.flatten()])
    print('    labels:', [reverse_dictionary[li] for li in labels.flatten()])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with skip_window = 1:
#     batch: ['anarchism', 'as', 'originated', 'a', 'as', 'term', 'a', 'of', 'term', 'abuse', 'of', 'first']
#     labels: ['originated', 'as', 'a', 'term', 'of', 'abuse']
#
# with skip_window = 2:
#     batch: ['originated', 'anarchism', 'a', 'term', 'as', 'originated', 'term', 'of', 'a', 'as', 'of', 'abuse', 'term', 'a', 'abuse', 'first']
#     labels: ['as', 'a', 'term', 'of']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
train_size = batch_size - 2 * skip_window
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[train_size, skip_window*2])
  train_labels = tf.placeholder(tf.int32, shape=[train_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  embed_sum = tf.reduce_sum(embed, 1)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed_sum,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
embed.get_shape()
# Out:
# TensorShape([Dimension(126), Dimension(2), Dimension(128)])

# %%
embed_sum.get_shape()
# Out:
# TensorShape([Dimension(126), Dimension(128)])

# %%
num_steps = 120001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch_cbow(
      batch_size, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in xrange(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in xrange(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.382590
# Nearest to of: sidonia, werke, rockers, nihon, boleyn, gripped, cu, devanagari,
# Nearest to this: khoikhoi, epirus, blast, lactamase, intellectually, lifeforms, indexes, lawfully,
# Nearest to they: adys, radars, pipeline, baryogenesis, compatibility, vis, mosquitia, qe,
# Nearest to five: tac, obtuse, weiss, menger, khazar, horseman, smalltalk, harpo,
# Nearest to the: cp, infer, notoriety, impoverishment, hologram, fork, affluence, thalamus,
# Nearest to state: constituted, advocates, cash, torino, inquire, profitable, scribes, dries,
# Nearest to had: wrangler, cast, norwood, morita, refund, forecasts, requested, megas,
# Nearest to about: concerted, garnet, intracellular, ppg, diesels, tynwald, php, kimmel,
# Nearest to would: trapdoor, alexandra, behe, rife, iranian, haddo, recounted, ephraim,
# Nearest to if: kato, rays, balderus, melodies, poseidon, injustice, surged, noodle,
# Nearest to world: scandinavians, pcbs, hostels, discography, lasker, tina, kundalini, antipathy,
# Nearest to from: donated, cordial, scarlett, goin, hilda, congruence, paracelsus, factbook,
# Nearest to was: locality, oxygenated, wasteland, phoenician, bodmin, pseudo, lakeshore, unemployed,
# Nearest to are: challenged, indicated, hedge, kursk, mmix, oxidise, polygonal, stormed,
# Nearest to a: kuan, reversing, finish, home, vantaa, xenakis, heinemann, notables,
# Nearest to s: dissonance, poitou, harnesses, altitudes, mutual, steady, expound, bootstrap,
# Average loss at step 2000: 3.599739
# Average loss at step 4000: 3.203993
# Average loss at step 6000: 3.301967
# Average loss at step 8000: 3.259056
# Average loss at step 10000: 3.287652
# Nearest to of: submersible, paternal, for, primaries, tempting, yeager, shit, dua,
# Nearest to this: which, it, the, that, its, neurologic, harvesting, bittersweet,
# Nearest to they: he, she, you, there, potatoes, we, lapse, it,
# Nearest to five: six, eight, four, seven, three, nine, two, zero,
# Nearest to the: a, its, this, an, sturgeon, his, their, piety,
# Nearest to state: miniature, constituted, cash, kingdom, inquire, meg, eisner, rotary,
# Nearest to had: has, have, was, were, simulations, hath, osr, norwood,
# Nearest to about: kimmel, concerted, privacy, computed, on, swastika, hectare, quad,
# Nearest to would: can, will, could, may, might, must, should, to,
# Nearest to if: when, injustice, bloggers, melodies, scarlet, kato, seydlitz, emet,
# Nearest to world: skeptics, laurel, isuzu, grains, rides, talkie, u, scandinavians,
# Nearest to from: into, meteorites, at, with, shafi, through, in, goin,
# Nearest to was: is, were, had, became, has, been, locality, blossoms,
# Nearest to are: were, is, have, mutants, tricky, ripening, ethica, flutist,
# Nearest to a: the, spikes, groupe, meteorological, very, dressing, runways, wrought,
# Nearest to s: intensities, his, oxygenated, amadeus, linker, haired, seater, seds,
# Average loss at step 12000: 3.255631
# Average loss at step 14000: 3.096308
# Average loss at step 16000: 3.163653
# Average loss at step 18000: 3.126579
# Average loss at step 20000: 3.155295
# Nearest to of: deoxygenated, in, heaps, and, vindication, vulgate, for, derry,
# Nearest to this: which, it, that, the, there, some, preside, any,
# Nearest to they: there, we, you, he, she, it, these, i,
# Nearest to five: four, six, seven, eight, three, zero, nine, two,
# Nearest to the: its, their, this, a, his, any, platonist, cusco,
# Nearest to state: constituted, cash, ilinden, komm, kingdom, miniature, instant, eisner,
# Nearest to had: has, have, was, morita, were, ve, hath, having,
# Nearest to about: on, concerted, flashlight, hectare, privacy, apartment, kimmel, posit,
# Nearest to would: could, will, can, may, might, should, must, does,
# Nearest to if: when, though, dba, gemstones, halicarnassus, pleases, however, showed,
# Nearest to world: talkie, isuzu, u, properties, neumann, civil, putative, skeptics,
# Nearest to from: into, through, after, hennepin, moivre, apps, evelyn, back,
# Nearest to was: is, has, had, became, were, been, headgear, does,
# Nearest to are: were, have, is, devastating, tricky, ethica, mutants, sends,
# Nearest to a: no, the, wrought, another, leftrightarrow, every, any, quaternary,
# Nearest to s: seater, intensities, whose, haired, clash, and, moira, balboa,
# Average loss at step 22000: 2.964071
# Average loss at step 24000: 2.830086
# Average loss at step 26000: 2.889087
# Average loss at step 28000: 3.051976
# Average loss at step 30000: 2.935036
# Nearest to of: submersible, middlesex, caenorhabditis, dua, fulcher, in, anthropomorphic, heaps,
# Nearest to this: it, which, what, that, the, any, some, ripping,
# Nearest to they: we, there, he, you, she, it, who, these,
# Nearest to five: seven, eight, four, six, nine, three, zero, two,
# Nearest to the: its, their, his, a, leeward, this, her, any,
# Nearest to state: miniature, fading, pits, assets, creations, almoravides, sorties, exempted,
# Nearest to had: has, have, was, having, were, since, ve, became,
# Nearest to about: discussing, privacy, butyl, over, flashlight, computed, hectare, on,
# Nearest to would: will, could, can, may, might, must, should, does,
# Nearest to if: when, though, before, where, because, computations, gemstones, dba,
# Nearest to world: u, talkie, sardaukar, isuzu, putative, coroner, fantasyland, dugout,
# Nearest to from: into, through, shafi, after, suk, factbook, hennepin, in,
# Nearest to was: is, became, had, has, were, being, does, been,
# Nearest to are: were, have, is, include, defected, superseding, be, including,
# Nearest to a: the, another, any, its, runways, quaternary, ranking, disarmed,
# Nearest to s: haired, intensities, whose, androgens, croft, her, multistage, moira,
# Average loss at step 32000: 2.933441
# Average loss at step 34000: 3.017494
# Average loss at step 36000: 2.917303
# Average loss at step 38000: 2.932546
# Average loss at step 40000: 2.845279
# Nearest to of: devotee, weighty, pistons, ernst, wiktionary, corned, arion, s,
# Nearest to this: which, it, the, what, neurobiology, some, another, ripping,
# Nearest to they: we, there, he, she, you, it, these, however,
# Nearest to five: seven, eight, six, three, nine, four, zero, two,
# Nearest to the: its, this, their, these, piety, a, our, timbres,
# Nearest to state: government, states, levant, sorties, enunciated, venetians, assets, city,
# Nearest to had: has, have, was, were, since, having, ve, never,
# Nearest to about: on, gehrig, differing, over, wilkins, butyl, bogside, around,
# Nearest to would: will, could, can, may, should, might, must, does,
# Nearest to if: when, though, where, say, before, shall, because, spears,
# Nearest to world: talkie, u, country, sardaukar, moon, comparatively, nation, fantasyland,
# Nearest to from: through, into, in, after, across, shafi, factbook, between,
# Nearest to was: is, became, had, were, has, being, be, blossoms,
# Nearest to are: were, have, include, is, sends, those, be, being,
# Nearest to a: quaternary, another, the, any, reviewers, disarmed, monck, enough,
# Nearest to s: whose, intensities, lichfield, hindi, william, todd, aron, androgens,
# Average loss at step 42000: 2.862641
# Average loss at step 44000: 2.809535
# Average loss at step 46000: 2.855814
# Average loss at step 48000: 2.864908
# Average loss at step 50000: 2.891423
# Nearest to of: including, seng, submersible, tonle, ibizan, cheshire, heaps, hazaras,
# Nearest to this: which, what, it, the, another, polyethylene, any, knowledgeable,
# Nearest to they: we, you, there, he, she, i, these, it,
# Nearest to five: seven, four, six, eight, three, zero, nine, two,
# Nearest to the: its, their, this, any, a, our, lathe, mamre,
# Nearest to state: government, states, assets, levant, kingdom, ilinden, city, stranded,
# Nearest to had: has, have, was, hath, having, never, ve, since,
# Nearest to about: over, around, discussing, jacinto, wilkins, stumble, on, schiff,
# Nearest to would: will, could, can, may, might, should, must, cannot,
# Nearest to if: when, though, before, where, however, although, did, since,
# Nearest to world: talkie, rafik, sardaukar, katha, caches, eyesight, years, u,
# Nearest to from: into, through, under, after, during, disavow, decapitated, suk,
# Nearest to was: is, became, had, were, has, appeared, been, remained,
# Nearest to are: were, have, include, is, remain, intertwined, devastating, be,
# Nearest to a: the, quaternary, another, enough, groupe, no, ranking, spikes,
# Nearest to s: intensities, isbn, whose, suppressive, michel, seater, kampen, fulani,
# Average loss at step 52000: 2.868610
# Average loss at step 54000: 2.730481
# Average loss at step 56000: 2.870615
# Average loss at step 58000: 2.864414
# Average loss at step 60000: 2.801830
# Nearest to of: in, assize, submersible, reconquista, hazaras, djbdns, dua, during,
# Nearest to this: which, the, it, nijmegen, bypass, some, ripping, multiplayer,
# Nearest to they: we, he, she, you, there, it, who, utub,
# Nearest to five: four, six, seven, eight, three, nine, two, zero,
# Nearest to the: their, its, this, his, a, confining, some, kensington,
# Nearest to state: levant, government, ilinden, deregulation, states, assets, chee, legality,
# Nearest to had: has, have, having, ve, was, ever, since, never,
# Nearest to about: over, gehrig, schiff, discussing, wilkins, jacinto, stumble, privacy,
# Nearest to would: will, could, may, can, might, should, must, cannot,
# Nearest to if: when, where, though, before, although, since, ceding, deems,
# Nearest to world: talkie, u, nation, season, coroner, crimean, civil, indemnity,
# Nearest to from: through, into, during, after, in, det, across, before,
# Nearest to was: is, became, were, has, had, being, be, been,
# Nearest to are: were, is, include, have, remain, ethica, those, moss,
# Nearest to a: another, the, obfuscation, enough, quaternary, spikes, monck, any,
# Nearest to s: isbn, whose, intensities, aron, lichfield, multistage, ribeira, kampen,
# Average loss at step 62000: 2.853548
# Average loss at step 64000: 2.821980
# Average loss at step 66000: 2.741490
# Average loss at step 68000: 2.689973
# Average loss at step 70000: 2.794661
# Nearest to of: spatial, submersible, weighty, djbdns, including, hazaras, deniers, while,
# Nearest to this: which, it, what, the, neurobiology, nationhood, latter, that,
# Nearest to they: we, he, there, you, she, it, ahmet, basically,
# Nearest to five: four, six, seven, eight, three, nine, zero, two,
# Nearest to the: its, a, this, their, quesada, his, kensington, neurologic,
# Nearest to state: states, government, kingdom, levant, deregulation, ilinden, city, chee,
# Nearest to had: has, have, was, having, were, ve, recently, nissan,
# Nearest to about: approximately, gehrig, around, springer, schiff, discussing, on, regarding,
# Nearest to would: will, could, might, may, can, should, must, cannot,
# Nearest to if: when, though, before, where, since, without, did, until,
# Nearest to world: u, nation, crimean, talkie, ergaster, indemnity, fantasyland, katha,
# Nearest to from: through, during, into, across, beyond, mensch, between, before,
# Nearest to was: is, became, were, has, had, islet, been, eyeglasses,
# Nearest to are: were, have, including, include, is, those, contain, remain,
# Nearest to a: another, the, obfuscation, enough, quaternary, altercation, parliamentarian, forbes,
# Nearest to s: isbn, whose, haired, intensities, nashe, abdel, mangaverse, olney,
# Average loss at step 72000: 2.810272
# Average loss at step 74000: 2.793451
# Average loss at step 76000: 2.803369
# Average loss at step 78000: 2.860959
# Average loss at step 80000: 2.793892
# Nearest to of: including, submersible, pancreatic, tonle, limericks, from, during, ozzfest,
# Nearest to this: it, which, what, polyethylene, the, mits, any, eisler,
# Nearest to they: we, he, you, there, she, it, then, i,
# Nearest to five: seven, three, eight, four, six, nine, two, zero,
# Nearest to the: its, their, his, nijmegen, our, whose, this, charleroi,
# Nearest to state: states, government, city, kingdom, provability, levant, chee, assets,
# Nearest to had: has, have, having, was, were, attempted, never, ve,
# Nearest to about: regarding, over, around, discussing, approximately, concerning, on, gehrig,
# Nearest to would: could, will, might, may, should, can, must, cannot,
# Nearest to if: when, since, though, where, maggots, before, then, loxodonta,
# Nearest to world: nation, crimean, indemnity, cpu, katha, universe, u, talkie,
# Nearest to from: through, during, into, after, before, howling, via, maru,
# Nearest to was: is, became, had, were, has, seems, be, appears,
# Nearest to are: were, have, is, include, remain, exist, those, contain,
# Nearest to a: another, quaternary, every, disarmed, runways, altercation, any, obfuscation,
# Nearest to s: whose, isbn, intensities, ribeira, embryonic, partnerships, haired, destabilizing,
# Average loss at step 82000: 2.809327
# Average loss at step 84000: 2.720990
# Average loss at step 86000: 2.734268
# Average loss at step 88000: 2.768859
# Average loss at step 90000: 2.754717
# Nearest to of: in, although, and, including, hazaras, submersible, assize, within,
# Nearest to this: it, which, the, nationhood, multiplayer, another, accommodations, what,
# Nearest to they: we, there, you, he, she, i, these, it,
# Nearest to five: seven, six, four, eight, three, zero, two, nine,
# Nearest to the: its, his, their, this, our, any, a, these,
# Nearest to state: states, kingdom, government, city, levant, provability, press, assets,
# Nearest to had: has, have, were, was, having, attempted, since, chose,
# Nearest to about: regarding, around, discussing, over, concerning, arguably, that, saracens,
# Nearest to would: will, could, might, should, can, must, may, cannot,
# Nearest to if: when, though, where, maggots, should, since, exorcist, then,
# Nearest to world: nation, universe, crimean, u, indemnity, talkie, shoe, honoring,
# Nearest to from: through, into, in, across, during, hennepin, between, after,
# Nearest to was: is, became, had, were, has, seems, appears, remained,
# Nearest to are: were, have, include, remain, is, those, exist, contain,
# Nearest to a: another, quaternary, enough, every, runways, any, the, obfuscation,
# Nearest to s: isbn, intensities, aron, whose, hawkins, partnerships, heiden, korca,
# Average loss at step 92000: 2.631547
# Average loss at step 94000: 2.735230
# Average loss at step 96000: 2.750662
# Average loss at step 98000: 2.728950
# Average loss at step 100000: 2.629448
# Nearest to of: in, including, like, submersible, include, hazaras, meritocratic, for,
# Nearest to this: which, it, the, multiplayer, situated, another, barisan, cartographic,
# Nearest to they: we, he, you, there, she, it, these, i,
# Nearest to five: seven, four, six, eight, three, nine, two, zero,
# Nearest to the: its, their, our, this, a, his, storefront, baldr,
# Nearest to state: government, states, chee, kingdom, bowers, gk, levant, regions,
# Nearest to had: have, has, was, having, were, ever, morita, provides,
# Nearest to about: approximately, computed, regarding, discussing, around, concerning, stumble, arguably,
# Nearest to would: might, could, will, can, should, may, must, cannot,
# Nearest to if: when, though, before, since, did, because, where, although,
# Nearest to world: nation, crimean, indemnity, universe, honoring, wwii, europe, talkie,
# Nearest to from: through, into, during, after, mensch, amadeus, under, via,
# Nearest to was: is, became, had, has, were, appears, seems, becomes,
# Nearest to are: were, include, is, have, remain, contain, exist, be,
# Nearest to a: another, the, any, quaternary, disarmed, instituting, runways, obfuscation,
# Nearest to s: fielding, intensities, haired, whose, heinz, mike, aron, abdel,
# Average loss at step 102000: 2.638066
# Average loss at step 104000: 2.683515
# Average loss at step 106000: 2.727661
# Average loss at step 108000: 2.691503
# Average loss at step 110000: 2.577274
# Nearest to of: weighty, in, hazaras, deniers, for, including, reconquista, submersible,
# Nearest to this: which, it, another, henchman, some, latter, instead, situated,
# Nearest to they: we, you, he, there, she, it, utub, these,
# Nearest to five: six, seven, eight, four, three, nine, two, zero,
# Nearest to the: its, their, our, charleroi, a, his, whose, timbres,
# Nearest to state: government, states, levant, assets, legality, purified, dhabi, ilinden,
# Nearest to had: has, have, having, was, were, barrington, attempted, never,
# Nearest to about: approximately, computed, discussing, regarding, around, concerning, over, arguably,
# Nearest to would: will, could, might, should, can, may, must, cannot,
# Nearest to if: when, though, before, where, since, unless, because, after,
# Nearest to world: nation, crimean, universe, european, u, talkie, wwii, honoring,
# Nearest to from: through, during, across, into, via, beyond, after, amadeus,
# Nearest to was: is, became, had, has, were, becomes, seems, been,
# Nearest to are: were, include, is, have, contain, exist, remain, including,
# Nearest to a: another, the, runways, quaternary, obfuscation, instituting, every, spikes,
# Nearest to s: whose, intensities, ribeira, abdel, isbn, partnerships, hawkins, heiden,
# Average loss at step 112000: 2.725490
# Average loss at step 114000: 2.748867
# Average loss at step 116000: 2.623583
# Average loss at step 118000: 2.677556
# Average loss at step 120000: 2.662323
# Nearest to of: in, primaries, hazaras, weighty, for, submersible, and, spatial,
# Nearest to this: it, which, what, another, nationhood, the, there, similar,
# Nearest to they: we, you, there, he, she, it, these, sommerfeld,
# Nearest to five: six, four, eight, seven, three, nine, zero, two,
# Nearest to the: their, our, its, each, any, your, a, some,
# Nearest to state: government, states, legality, chee, assets, deregulation, dayan, city,
# Nearest to had: has, have, having, was, were, barrington, attempted, eventually,
# Nearest to about: approximately, discussing, around, computed, concerning, regarding, told, over,
# Nearest to would: will, could, might, should, may, can, must, cannot,
# Nearest to if: when, though, where, since, before, unless, after, without,
# Nearest to world: nation, crimean, wwii, european, europe, universe, talkie, indemnity,
# Nearest to from: through, across, after, into, during, beyond, via, amadeus,
# Nearest to was: is, became, had, seems, becomes, has, were, been,
# Nearest to are: were, include, is, remain, have, exist, be, contain,
# Nearest to a: another, every, the, no, any, enough, spikes, altercation,
# Nearest to s: whose, intensities, isbn, haired, abdel, ribeira, partnerships, hawkins,
