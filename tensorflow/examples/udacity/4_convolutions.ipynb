# %% [markdown]
# Deep Learning
# =============
#
# Assignment 4
# ------------
#
# Previously in `2_fullyconnected.ipynb` and `3_regularization.ipynb`, we trained fully connected networks to classify [notMNIST](http://yaroslavvb.blogspot.com/2011/09/notmnist-dataset.html) characters.
#
# The goal of this assignment is make the neural network convolutional.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
from __future__ import print_function
import numpy as np
import tensorflow as tf
from six.moves import cPickle as pickle
from six.moves import range

# %%
pickle_file = 'notMNIST.pickle'

with open(pickle_file, 'rb') as f:
  save = pickle.load(f)
  train_dataset = save['train_dataset']
  train_labels = save['train_labels']
  valid_dataset = save['valid_dataset']
  valid_labels = save['valid_labels']
  test_dataset = save['test_dataset']
  test_labels = save['test_labels']
  del save  # hint to help gc free up memory
  print('Training set', train_dataset.shape, train_labels.shape)
  print('Validation set', valid_dataset.shape, valid_labels.shape)
  print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (200000, 28, 28) (200000,)
# Validation set (10000, 28, 28) (10000,)
# Test set (10000, 28, 28) (10000,)

# %% [markdown]
# Reformat into a TensorFlow-friendly shape:
# - convolutions need the image data formatted as a cube (width by height by #channels)
# - labels as float 1-hot encodings.

# %%
image_size = 28
num_labels = 10
num_channels = 1 # grayscale

import numpy as np

def reformat(dataset, labels):
  dataset = dataset.reshape(
    (-1, image_size, image_size, num_channels)).astype(np.float32)
  labels = (np.arange(num_labels) == labels[:,None]).astype(np.float32)
  return dataset, labels
train_dataset, train_labels = reformat(train_dataset, train_labels)
valid_dataset, valid_labels = reformat(valid_dataset, valid_labels)
test_dataset, test_labels = reformat(test_dataset, test_labels)
print('Training set', train_dataset.shape, train_labels.shape)
print('Validation set', valid_dataset.shape, valid_labels.shape)
print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (200000, 28, 28, 1) (200000, 10)
# Validation set (10000, 28, 28, 1) (10000, 10)
# Test set (10000, 28, 28, 1) (10000, 10)

# %%
def accuracy(predictions, labels):
  return (100.0 * np.sum(np.argmax(predictions, 1) == np.argmax(labels, 1))
          / predictions.shape[0])

# %% [markdown]
# Let's build a small network with two convolutional layers, followed by one fully connected layer. Convolutional networks are more expensive computationally, so we'll limit its depth and number of fully connected nodes.

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth]))
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
  layer3_weights = tf.Variable(tf.truncated_normal(
      [image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
  # Model.
  def model(data):
    conv = tf.nn.conv2d(data, layer1_weights, [1, 2, 2, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer1_biases)
    conv = tf.nn.conv2d(hidden, layer2_weights, [1, 2, 2, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer2_biases)
    shape = hidden.get_shape().as_list()
    reshape = tf.reshape(hidden, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    return tf.matmul(hidden, layer4_weights) + layer4_biases
  
  # Training computation.
  logits = model(tf_train_dataset)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(logits, tf_train_labels))
    
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
# ?tf.nn.conv2d

# %%
num_steps = 1001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 2.738682
# Minibatch accuracy: 12.5%
# Validation accuracy: 10.0%
# Minibatch loss at step 50: 1.507602
# Minibatch accuracy: 56.2%
# Validation accuracy: 50.7%
# Minibatch loss at step 100: 0.689998
# Minibatch accuracy: 62.5%
# Validation accuracy: 65.5%
# Minibatch loss at step 150: 1.052852
# Minibatch accuracy: 75.0%
# Validation accuracy: 74.1%
# Minibatch loss at step 200: 1.020899
# Minibatch accuracy: 68.8%
# Validation accuracy: 77.7%
# Minibatch loss at step 250: 0.790542
# Minibatch accuracy: 62.5%
# Validation accuracy: 78.5%
# Minibatch loss at step 300: 0.356014
# Minibatch accuracy: 93.8%
# Validation accuracy: 78.6%
# Minibatch loss at step 350: 1.118137
# Minibatch accuracy: 62.5%
# Validation accuracy: 79.5%
# Minibatch loss at step 400: 0.473761
# Minibatch accuracy: 87.5%
# Validation accuracy: 79.5%
# Minibatch loss at step 450: 0.417961
# Minibatch accuracy: 87.5%
# Validation accuracy: 79.5%
# Minibatch loss at step 500: 0.359833
# Minibatch accuracy: 87.5%
# Validation accuracy: 80.1%
# Minibatch loss at step 550: 0.453701
# Minibatch accuracy: 87.5%
# Validation accuracy: 80.7%
# Minibatch loss at step 600: 0.325723
# Minibatch accuracy: 93.8%
# Validation accuracy: 81.4%
# Minibatch loss at step 650: 0.707463
# Minibatch accuracy: 75.0%
# Validation accuracy: 81.4%
# Minibatch loss at step 700: 0.445817
# Minibatch accuracy: 81.2%
# Validation accuracy: 81.2%
# Minibatch loss at step 750: 0.967251
# Minibatch accuracy: 75.0%
# Validation accuracy: 81.1%
# Minibatch loss at step 800: 0.425233
# Minibatch accuracy: 81.2%
# Validation accuracy: 81.8%
# Minibatch loss at step 850: 0.370241
# Minibatch accuracy: 93.8%
# Validation accuracy: 82.2%
# Minibatch loss at step 900: 0.341909
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.3%
# Minibatch loss at step 950: 0.141648
# Minibatch accuracy: 93.8%
# Validation accuracy: 83.2%
# Minibatch loss at step 1000: 0.559572
# Minibatch accuracy: 75.0%
# Validation accuracy: 82.3%
# Test accuracy: 89.1%

# %% [markdown]
# ---
# Problem 1
# ---------
#
# The convolutional model above uses convolutions with stride 2 to reduce the dimensionality. Replace the strides by a max pooling operation (`nn.max_pool()`) of stride 2 and kernel size 2.
#
# ---

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth]))
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
  layer3_weights = tf.Variable(tf.truncated_normal(
      [image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
  # Model.
  def model(data):
    conv = tf.nn.conv2d(data, layer1_weights, [1, 1, 1, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer1_biases)
    pool = tf.nn.max_pool(hidden, ksize=[1,2,2,1], strides=[1,2,2,1], padding='SAME')
    conv = tf.nn.conv2d(pool, layer2_weights, [1, 1, 1, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer2_biases)
    pool = tf.nn.max_pool(hidden, ksize=[1,2,2,1], strides=[1,2,2,1], padding='SAME')
    shape = pool.get_shape().as_list()
    reshape = tf.reshape(pool, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    return tf.matmul(hidden, layer4_weights) + layer4_biases
  
  # Training computation.
  logits = model(tf_train_dataset)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(logits, tf_train_labels))
    
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 1001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 3.481056
# Minibatch accuracy: 6.2%
# Validation accuracy: 10.0%
# Minibatch loss at step 50: 2.103223
# Minibatch accuracy: 31.2%
# Validation accuracy: 23.4%
# Minibatch loss at step 100: 0.947966
# Minibatch accuracy: 68.8%
# Validation accuracy: 52.4%
# Minibatch loss at step 150: 1.315501
# Minibatch accuracy: 56.2%
# Validation accuracy: 68.4%
# Minibatch loss at step 200: 1.067225
# Minibatch accuracy: 75.0%
# Validation accuracy: 76.1%
# Minibatch loss at step 250: 0.932141
# Minibatch accuracy: 68.8%
# Validation accuracy: 77.6%
# Minibatch loss at step 300: 0.280129
# Minibatch accuracy: 93.8%
# Validation accuracy: 79.8%
# Minibatch loss at step 350: 1.120847
# Minibatch accuracy: 68.8%
# Validation accuracy: 81.4%
# Minibatch loss at step 400: 0.642692
# Minibatch accuracy: 81.2%
# Validation accuracy: 80.7%
# Minibatch loss at step 450: 0.321567
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.1%
# Minibatch loss at step 500: 0.436784
# Minibatch accuracy: 87.5%
# Validation accuracy: 81.9%
# Minibatch loss at step 550: 0.479673
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.2%
# Minibatch loss at step 600: 0.200376
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.3%
# Minibatch loss at step 650: 0.538679
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.6%
# Minibatch loss at step 700: 0.649097
# Minibatch accuracy: 75.0%
# Validation accuracy: 83.4%
# Minibatch loss at step 750: 0.781091
# Minibatch accuracy: 75.0%
# Validation accuracy: 83.5%
# Minibatch loss at step 800: 0.497400
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.5%
# Minibatch loss at step 850: 0.373567
# Minibatch accuracy: 93.8%
# Validation accuracy: 84.2%
# Minibatch loss at step 900: 0.371640
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.0%
# Minibatch loss at step 950: 0.070404
# Minibatch accuracy: 100.0%
# Validation accuracy: 84.9%
# Minibatch loss at step 1000: 0.695046
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.8%
# Test accuracy: 90.8%

# %% [markdown]
# ---
# Problem 2
# ---------
#
# Try to get the best performance you can using a convolutional net. Look for example at the classic [LeNet5](http://yann.lecun.com/exdb/lenet/) architecture, adding Dropout, and/or adding learning rate decay.
#
# ---

# %%
batch_size = 16
patch_size = 5
depth1 = 6
depth2 = 16
num_hidden = 64
num_hidden2 = 32

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth1], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth1]))

  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth1, depth2], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth2]))
  layer3_weights = tf.Variable(tf.truncated_normal(
      [image_size // 4 * image_size // 4 * depth2, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))

  layer4_weights = tf.Variable(tf.truncated_normal(
        [num_hidden, num_hidden2], stddev=0.1))
  layer_4_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden2]))

  layer5_weights = tf.Variable(tf.truncated_normal(
      [num_hidden2, num_labels], stddev=0.1))
  layer5_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))

  
  # Model
  def model(data, dropout=False):
    conv = tf.nn.conv2d(data, layer1_weights, [1, 1, 1, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer1_biases)
    pool = tf.nn.max_pool(hidden, ksize=[1,2,2,1], strides=[1,2,2,1], padding='SAME')
    
    conv = tf.nn.conv2d(pool, layer2_weights, [1, 1, 1, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer2_biases)
    pool = tf.nn.max_pool(hidden, ksize=[1,2,2,1], strides=[1,2,2,1], padding='SAME')

    shape = pool.get_shape().as_list()
    reshape = tf.reshape(pool, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    
    if dropout:
        layer4_weights_maybe_dropout = tf.nn.dropout(layer4_weights, keep_prob=0.5)
    else:
        layer4_weights_maybe_dropout = layer4_weights
    hidden2 = tf.nn.relu(tf.matmul(hidden, layer4_weights_maybe_dropout)) + layer_4_biases
    return tf.matmul(hidden2, layer5_weights) + layer5_biases
  
  # Training computation.
  logits = model(tf_train_dataset, dropout=True)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(logits, tf_train_labels))
    
  # Optimizer.
  global_step = tf.Variable(0)  # count the number of steps taken.

  learning_rate = tf.train.exponential_decay(learning_rate=0.1, 
                                               global_step=global_step, 
                                              decay_steps=1,
                                              decay_rate=0.999)
    
  optimizer = tf.train.GradientDescentOptimizer(learning_rate).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 10001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 2.664636
# Minibatch accuracy: 6.2%
# Validation accuracy: 10.0%
# Minibatch loss at step 50: 2.328946
# Minibatch accuracy: 6.2%
# Validation accuracy: 10.0%
# Minibatch loss at step 100: 2.396563
# Minibatch accuracy: 6.2%
# Validation accuracy: 10.0%
# Minibatch loss at step 150: 2.382529
# Minibatch accuracy: 0.0%
# Validation accuracy: 10.0%
# Minibatch loss at step 200: 2.414695
# Minibatch accuracy: 12.5%
# Validation accuracy: 10.0%
# Minibatch loss at step 250: 2.262766
# Minibatch accuracy: 6.2%
# Validation accuracy: 10.0%
# Minibatch loss at step 300: 2.277493
# Minibatch accuracy: 12.5%
# Validation accuracy: 10.0%
# Minibatch loss at step 350: 2.520826
# Minibatch accuracy: 0.0%
# Validation accuracy: 10.0%
# Minibatch loss at step 400: 2.288530
# Minibatch accuracy: 12.5%
# Validation accuracy: 10.0%
# Minibatch loss at step 450: 2.319748
# Minibatch accuracy: 18.8%
# Validation accuracy: 10.0%
# Minibatch loss at step 500: 2.277275
# Minibatch accuracy: 31.2%
# Validation accuracy: 10.0%
# Minibatch loss at step 550: 2.320154
# Minibatch accuracy: 12.5%
# Validation accuracy: 10.0%
# Minibatch loss at step 600: 2.313649
# Minibatch accuracy: 12.5%
# Validation accuracy: 10.0%
# Minibatch loss at step 650: 2.302934
# Minibatch accuracy: 18.8%
# Validation accuracy: 19.2%
# Minibatch loss at step 700: 2.454034
# Minibatch accuracy: 6.2%
# Validation accuracy: 19.2%
# Minibatch loss at step 750: 1.820625
# Minibatch accuracy: 37.5%
# Validation accuracy: 27.7%
# Minibatch loss at step 800: 2.124779
# Minibatch accuracy: 12.5%
# Validation accuracy: 41.8%
# Minibatch loss at step 850: 1.347659
# Minibatch accuracy: 50.0%
# Validation accuracy: 42.4%
# Minibatch loss at step 900: 1.333348
# Minibatch accuracy: 68.8%
# Validation accuracy: 57.7%
# Minibatch loss at step 950: 0.923338
# Minibatch accuracy: 68.8%
# Validation accuracy: 66.8%
# Minibatch loss at step 1000: 0.777877
# Minibatch accuracy: 75.0%
# Validation accuracy: 67.1%
# Minibatch loss at step 1050: 0.823284
# Minibatch accuracy: 68.8%
# Validation accuracy: 71.3%
# Minibatch loss at step 1100: 0.673243
# Minibatch accuracy: 81.2%
# Validation accuracy: 74.5%
# Minibatch loss at step 1150: 1.300529
# Minibatch accuracy: 56.2%
# Validation accuracy: 76.6%
# Minibatch loss at step 1200: 0.889477
# Minibatch accuracy: 68.8%
# Validation accuracy: 78.6%
# Minibatch loss at step 1250: 0.994200
# Minibatch accuracy: 56.2%
# Validation accuracy: 78.2%
# Minibatch loss at step 1300: 1.180286
# Minibatch accuracy: 75.0%
# Validation accuracy: 80.8%
# Minibatch loss at step 1350: 0.891317
# Minibatch accuracy: 68.8%
# Validation accuracy: 81.5%
# Minibatch loss at step 1400: 1.031366
# Minibatch accuracy: 68.8%
# Validation accuracy: 81.7%
# Minibatch loss at step 1450: 0.894950
# Minibatch accuracy: 62.5%
# Validation accuracy: 81.2%
# Minibatch loss at step 1500: 1.542453
# Minibatch accuracy: 43.8%
# Validation accuracy: 81.4%
# Minibatch loss at step 1550: 0.095163
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.8%
# Minibatch loss at step 1600: 0.721787
# Minibatch accuracy: 75.0%
# Validation accuracy: 82.9%
# Minibatch loss at step 1650: 0.382292
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.9%
# Minibatch loss at step 1700: 0.537420
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.6%
# Minibatch loss at step 1750: 0.589485
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.2%
# Minibatch loss at step 1800: 0.312570
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.1%
# Minibatch loss at step 1850: 0.181681
# Minibatch accuracy: 93.8%
# Validation accuracy: 83.2%
# Minibatch loss at step 1900: 0.624097
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.7%
# Minibatch loss at step 1950: 0.742125
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.7%
# Minibatch loss at step 2000: 0.248496
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.2%
# Minibatch loss at step 2050: 0.456244
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.2%
# Minibatch loss at step 2100: 0.691134
# Minibatch accuracy: 75.0%
# Validation accuracy: 84.2%
# Minibatch loss at step 2150: 0.473528
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.8%
# Minibatch loss at step 2200: 0.526285
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.0%
# Minibatch loss at step 2250: 0.354384
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.3%
# Minibatch loss at step 2300: 0.634270
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.3%
# Minibatch loss at step 2350: 0.602659
# Minibatch accuracy: 75.0%
# Validation accuracy: 84.5%
# Minibatch loss at step 2400: 0.679427
# Minibatch accuracy: 68.8%
# Validation accuracy: 83.8%
# Minibatch loss at step 2450: 0.170548
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.4%
# Minibatch loss at step 2500: 0.445822
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.6%
# Minibatch loss at step 2550: 0.679835
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.1%
# Minibatch loss at step 2600: 0.636303
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.2%
# Minibatch loss at step 2650: 0.475088
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.2%
# Minibatch loss at step 2700: 0.307361
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.8%
# Minibatch loss at step 2750: 0.293142
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.3%
# Minibatch loss at step 2800: 0.242541
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.9%
# Minibatch loss at step 2850: 0.350198
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.2%
# Minibatch loss at step 2900: 0.804456
# Minibatch accuracy: 75.0%
# Validation accuracy: 85.8%
# Minibatch loss at step 2950: 0.393919
# Minibatch accuracy: 93.8%
# Validation accuracy: 84.0%
# Minibatch loss at step 3000: 0.680408
# Minibatch accuracy: 75.0%
# Validation accuracy: 85.8%
# Minibatch loss at step 3050: 0.094432
# Minibatch accuracy: 100.0%
# Validation accuracy: 86.1%
# Minibatch loss at step 3100: 0.402876
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.1%
# Minibatch loss at step 3150: 0.425199
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.7%
# Minibatch loss at step 3200: 0.647838
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.9%
# Minibatch loss at step 3250: 0.580593
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.0%
# Minibatch loss at step 3300: 0.766037
# Minibatch accuracy: 75.0%
# Validation accuracy: 85.8%
# Minibatch loss at step 3350: 0.216341
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.5%
# Minibatch loss at step 3400: 0.310924
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.2%
# Minibatch loss at step 3450: 0.268753
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.1%
# Minibatch loss at step 3500: 0.435927
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.8%
# Minibatch loss at step 3550: 0.240969
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.1%
# Minibatch loss at step 3600: 0.427748
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.6%
# Minibatch loss at step 3650: 0.586909
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.9%
# Minibatch loss at step 3700: 0.022562
# Minibatch accuracy: 100.0%
# Validation accuracy: 85.9%
# Minibatch loss at step 3750: 0.997957
# Minibatch accuracy: 62.5%
# Validation accuracy: 86.4%
# Minibatch loss at step 3800: 0.676250
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.8%
# Minibatch loss at step 3850: 0.534190
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.2%
# Minibatch loss at step 3900: 0.549176
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.7%
# Minibatch loss at step 3950: 0.622319
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.3%
# Minibatch loss at step 4000: 0.290904
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.8%
# Minibatch loss at step 4050: 0.575017
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.0%
# Minibatch loss at step 4100: 0.266974
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.5%
# Minibatch loss at step 4150: 0.415884
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.0%
# Minibatch loss at step 4200: 0.782186
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.2%
# Minibatch loss at step 4250: 0.627691
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.8%
# Minibatch loss at step 4300: 0.370921
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.8%
# Minibatch loss at step 4350: 1.013897
# Minibatch accuracy: 75.0%
# Validation accuracy: 85.7%
# Minibatch loss at step 4400: 0.569954
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.5%
# Minibatch loss at step 4450: 0.510063
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.4%
# Minibatch loss at step 4500: 0.046593
# Minibatch accuracy: 100.0%
# Validation accuracy: 87.0%
# Minibatch loss at step 4550: 0.290121
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.7%
# Minibatch loss at step 4600: 1.087329
# Minibatch accuracy: 75.0%
# Validation accuracy: 86.1%
# Minibatch loss at step 4650: 0.188692
# Minibatch accuracy: 100.0%
# Validation accuracy: 86.3%
# Minibatch loss at step 4700: 0.440894
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.7%
# Minibatch loss at step 4750: 0.947450
# Minibatch accuracy: 62.5%
# Validation accuracy: 86.0%
# Minibatch loss at step 4800: 0.427196
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.8%
# Minibatch loss at step 4850: 0.679826
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.0%
# Minibatch loss at step 4900: 0.219436
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.8%
# Minibatch loss at step 4950: 0.551432
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.1%
# Minibatch loss at step 5000: 0.877280
# Minibatch accuracy: 75.0%
# Validation accuracy: 87.1%
# Minibatch loss at step 5050: 0.838379
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.5%
# Minibatch loss at step 5100: 0.450641
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.2%
# Minibatch loss at step 5150: 0.361614
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.2%
# Minibatch loss at step 5200: 0.148661
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.2%
# Minibatch loss at step 5250: 0.011434
# Minibatch accuracy: 100.0%
# Validation accuracy: 87.0%
# Minibatch loss at step 5300: 0.338892
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.7%
# Minibatch loss at step 5350: 0.323209
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.4%
# Minibatch loss at step 5400: 0.393081
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.9%
# Minibatch loss at step 5450: 0.398234
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.4%
# Minibatch loss at step 5500: 0.431453
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.4%
# Minibatch loss at step 5550: 0.241027
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.2%
# Minibatch loss at step 5600: 0.118748
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.5%
# Minibatch loss at step 5650: 0.504363
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.4%
# Minibatch loss at step 5700: 0.612459
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.6%
# Minibatch loss at step 5750: 0.795962
# Minibatch accuracy: 68.8%
# Validation accuracy: 87.4%
# Minibatch loss at step 5800: 0.636496
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.3%
# Minibatch loss at step 5850: 0.074213
# Minibatch accuracy: 100.0%
# Validation accuracy: 86.8%
# Minibatch loss at step 5900: 0.970576
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.3%
# Minibatch loss at step 5950: 0.205224
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.1%
# Minibatch loss at step 6000: 0.674023
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.2%
# Minibatch loss at step 6050: 0.707833
# Minibatch accuracy: 75.0%
# Validation accuracy: 86.2%
# Minibatch loss at step 6100: 0.180831
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.6%
# Minibatch loss at step 6150: 0.404032
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.0%
# Minibatch loss at step 6200: 0.320244
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.7%
# Minibatch loss at step 6250: 0.439528
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.0%
# Minibatch loss at step 6300: 0.511816
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.4%
# Minibatch loss at step 6350: 0.544860
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.7%
# Minibatch loss at step 6400: 0.237685
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.2%
# Minibatch loss at step 6450: 0.644716
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.4%
# Minibatch loss at step 6500: 0.409387
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.8%
# Minibatch loss at step 6550: 0.633529
# Minibatch accuracy: 75.0%
# Validation accuracy: 82.9%
# Minibatch loss at step 6600: 0.540750
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.4%
# Minibatch loss at step 6650: 0.022696
# Minibatch accuracy: 100.0%
# Validation accuracy: 86.9%
# Minibatch loss at step 6700: 0.850162
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.2%
# Minibatch loss at step 6750: 0.509987
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.1%
# Minibatch loss at step 6800: 1.076988
# Minibatch accuracy: 68.8%
# Validation accuracy: 86.5%
# Minibatch loss at step 6850: 1.339820
# Minibatch accuracy: 68.8%
# Validation accuracy: 87.1%
# Minibatch loss at step 6900: 0.341194
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.2%
# Minibatch loss at step 6950: 0.531465
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.8%
# Minibatch loss at step 7000: 0.677472
# Minibatch accuracy: 75.0%
# Validation accuracy: 87.7%
# Minibatch loss at step 7050: 0.266372
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.6%
# Minibatch loss at step 7100: 1.362470
# Minibatch accuracy: 62.5%
# Validation accuracy: 87.2%
# Minibatch loss at step 7150: 0.353380
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.2%
# Minibatch loss at step 7200: 0.505138
# Minibatch accuracy: 75.0%
# Validation accuracy: 87.4%
# Minibatch loss at step 7250: 0.424523
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.3%
# Minibatch loss at step 7300: 0.501310
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.3%
# Minibatch loss at step 7350: 0.665523
# Minibatch accuracy: 75.0%
# Validation accuracy: 87.9%
# Minibatch loss at step 7400: 0.575182
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.8%
# Minibatch loss at step 7450: 0.155722
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.1%
# Minibatch loss at step 7500: 0.458806
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.8%
# Minibatch loss at step 7550: 0.021338
# Minibatch accuracy: 100.0%
# Validation accuracy: 87.9%
# Minibatch loss at step 7600: 0.166665
# Minibatch accuracy: 100.0%
# Validation accuracy: 87.7%
# Minibatch loss at step 7650: 0.284245
# Minibatch accuracy: 100.0%
# Validation accuracy: 87.2%
# Minibatch loss at step 7700: 0.099481
# Minibatch accuracy: 100.0%
# Validation accuracy: 87.6%
# Minibatch loss at step 7750: 0.431312
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.4%
# Minibatch loss at step 7800: 0.469770
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.2%
# Minibatch loss at step 7850: 0.516962
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.7%
# Minibatch loss at step 7900: 0.500041
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.0%
# Minibatch loss at step 7950: 0.264491
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.7%
# Minibatch loss at step 8000: 0.181717
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.8%
# Minibatch loss at step 8050: 0.298174
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.9%
# Minibatch loss at step 8100: 0.548567
# Minibatch accuracy: 75.0%
# Validation accuracy: 88.2%
# Minibatch loss at step 8150: 0.434952
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.1%
# Minibatch loss at step 8200: 0.298672
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.6%
# Minibatch loss at step 8250: 0.510947
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.7%
# Minibatch loss at step 8300: 0.484878
# Minibatch accuracy: 81.2%
# Validation accuracy: 88.1%
# Minibatch loss at step 8350: 0.411548
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.8%
# Minibatch loss at step 8400: 0.590819
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.0%
# Minibatch loss at step 8450: 0.605971
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.8%
# Minibatch loss at step 8500: 0.812089
# Minibatch accuracy: 81.2%
# Validation accuracy: 88.0%
# Minibatch loss at step 8550: 0.365990
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.7%
# Minibatch loss at step 8600: 0.489536
# Minibatch accuracy: 81.2%
# Validation accuracy: 88.2%
# Minibatch loss at step 8650: 0.031166
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.3%
# Minibatch loss at step 8700: 0.448356
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.3%
# Minibatch loss at step 8750: 0.425471
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.1%
# Minibatch loss at step 8800: 0.354846
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.9%
# Minibatch loss at step 8850: 0.150169
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.7%
# Minibatch loss at step 8900: 0.312119
# Minibatch accuracy: 81.2%
# Validation accuracy: 88.3%
# Minibatch loss at step 8950: 0.231051
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.0%
# Minibatch loss at step 9000: 0.279429
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.1%
# Minibatch loss at step 9050: 0.411709
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.1%
# Minibatch loss at step 9100: 0.013516
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.1%
# Minibatch loss at step 9150: 0.723382
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.7%
# Minibatch loss at step 9200: 0.554470
# Minibatch accuracy: 81.2%
# Validation accuracy: 88.1%
# Minibatch loss at step 9250: 0.640636
# Minibatch accuracy: 75.0%
# Validation accuracy: 87.8%
# Minibatch loss at step 9300: 0.438497
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.1%
# Minibatch loss at step 9350: 0.395484
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.8%
# Minibatch loss at step 9400: 0.213008
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.6%
# Minibatch loss at step 9450: 0.644300
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.4%
# Minibatch loss at step 9500: 0.663289
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.0%
# Minibatch loss at step 9550: 0.813556
# Minibatch accuracy: 68.8%
# Validation accuracy: 88.0%
# Minibatch loss at step 9600: 0.272858
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.5%
# Minibatch loss at step 9650: 0.653035
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.9%
# Minibatch loss at step 9700: 0.291069
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.0%
# Minibatch loss at step 9750: 0.229359
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.2%
# Minibatch loss at step 9800: 0.497523
# Minibatch accuracy: 81.2%
# Validation accuracy: 88.1%
# Minibatch loss at step 9850: 0.117064
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.1%
# Minibatch loss at step 9900: 0.072098
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.4%
# Minibatch loss at step 9950: 0.365987
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.2%
# Minibatch loss at step 10000: 0.412284
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.8%
# Test accuracy: 94.3%

# %%
batch_size = 128
hidden_layer1_size = 1024
hidden_layer2_size = 305
hidden_lastlayer_size = 75

use_multilayers = True

regularization_meta=0.03


graph = tf.Graph()
with graph.as_default():

  # Input data. For the training data, we use a placeholder that will be fed
  # at run time with a training minibatch.
  tf_train_dataset = tf.placeholder(tf.float32,
                                    shape=(batch_size, image_size * image_size))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  keep_prob = tf.placeholder(tf.float32)

  weights_layer1 = tf.Variable(
    tf.truncated_normal([image_size * image_size, hidden_layer1_size], stddev=0.0517))
  biases_layer1 = tf.Variable(tf.zeros([hidden_layer1_size]))

  if use_multilayers:
    weights_layer2 = tf.Variable(
      tf.truncated_normal([hidden_layer1_size, hidden_layer1_size], stddev=0.0441))
    biases_layer2 = tf.Variable(tf.zeros([hidden_layer1_size]))

    weights_layer3 = tf.Variable(
      tf.truncated_normal([hidden_layer1_size, hidden_layer2_size], stddev=0.0441))
    biases_layer3 = tf.Variable(tf.zeros([hidden_layer2_size]))
    
    weights_layer4 = tf.Variable(
      tf.truncated_normal([hidden_layer2_size, hidden_lastlayer_size], stddev=0.0809))
    biases_layer4 = tf.Variable(tf.zeros([hidden_lastlayer_size]))


  weights = tf.Variable(
    tf.truncated_normal([hidden_lastlayer_size if use_multilayers else hidden_layer1_size, num_labels], stddev=0.1632))
  biases = tf.Variable(tf.zeros([num_labels]))
  
    
  # get the NN models
  def getNN4Layer(dSet, use_dropout):
    input_to_layer1 = tf.matmul(dSet, weights_layer1) + biases_layer1
    hidden_layer1_output = tf.nn.relu(input_to_layer1)
    
    
    logits_hidden1 = None
    if use_dropout:
       dropout_hidden1 = tf.nn.dropout(hidden_layer1_output, keep_prob)
       logits_hidden1 = tf.matmul(dropout_hidden1, weights_layer2) + biases_layer2
    else:
      logits_hidden1 = tf.matmul(hidden_layer1_output, weights_layer2) + biases_layer2
    
    hidden_layer2_output = tf.nn.relu(logits_hidden1)
    
    logits_hidden2 = None
    if use_dropout:
       dropout_hidden2 = tf.nn.dropout(hidden_layer2_output, keep_prob)
       logits_hidden2 = tf.matmul(dropout_hidden2, weights_layer3) + biases_layer3
    else:
      logits_hidden2 = tf.matmul(hidden_layer2_output, weights_layer3) + biases_layer3
    
    
    hidden_layer3_output = tf.nn.relu(logits_hidden2)
    logits_hidden3 = None
    if use_dropout:
       dropout_hidden3 = tf.nn.dropout(hidden_layer3_output, keep_prob)
       logits_hidden3 = tf.matmul(dropout_hidden3, weights_layer4) + biases_layer4
    else:
      logits_hidden3 = tf.matmul(hidden_layer3_output, weights_layer4) + biases_layer4
    
    
    hidden_layer4_output = tf.nn.relu(logits_hidden3)
    logits = None
    if use_dropout:
       dropout_hidden4 = tf.nn.dropout(hidden_layer4_output, keep_prob)
       logits = tf.matmul(dropout_hidden4, weights) + biases
    else:
      logits = tf.matmul(hidden_layer4_output, weights) + biases
    
    return logits

  # get the NN models
  def getNN1Layer(dSet, use_dropout, w1, b1, w, b):
    input_to_layer1 = tf.matmul(dSet, w1) + b1
    hidden_layer1_output = tf.nn.relu(input_to_layer1)
        
    logits = None
    if use_dropout:
       dropout_hidden1 = tf.nn.dropout(hidden_layer1_output, keep_prob)
       logits = tf.matmul(dropout_hidden1, w) + b
    else:
      logits = tf.matmul(hidden_layer1_output, w) + b
    
    return logits

  
  
  # Training computation.
  logits = getNN4Layer(tf_train_dataset, True)  
  logits_valid = getNN4Layer(tf_valid_dataset, False)
  logits_test = getNN4Layer(tf_test_dataset, False)
    
  
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(logits, tf_train_labels))
  #loss_l2 = loss + (regularization_meta * (tf.nn.l2_loss(weights)))
  
  global_step = tf.Variable(0)  # count the number of steps taken.
  learning_rate = tf.train.exponential_decay(0.3, global_step, 3500, 0.86, staircase=True)
  
    
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(learning_rate).minimize(loss, global_step=global_step)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(logits_valid)
  test_prediction = tf.nn.softmax(logits_test)



num_steps = 95001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print("Initialized")
  for step in xrange(num_steps):
    # Pick an offset within the training data, which has been randomized.
    # Note: we could use better randomization across epochs.
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    
    # Generate a minibatch.
    batch_data = train_dataset[offset:(offset + batch_size), :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    
    # Prepare a dictionary telling the session where to feed the minibatch.
    # The key of the dictionary is the placeholder node of the graph to be fed,
    # and the value is the numpy array to feed to it.
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels, keep_prob:0.75}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 500 == 0):
      print("Minibatch loss at step", step, ":", l)
      print("Minibatch accuracy: %.1f%%" % accuracy(train_prediction.eval(feed_dict={tf_train_dataset : batch_data, tf_train_labels : batch_labels, keep_prob:1.0}), batch_labels))
      print("Validation accuracy: %.1f%%" % accuracy(
        valid_prediction.eval(feed_dict={keep_prob:1.0}), valid_labels))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-6b16d44592fb> in <module>()
#     106   # Training computation.
#     107   logits = getNN4Layer(tf_train_dataset, True)
# --> 108   logits_valid = getNN4Layer(tf_valid_dataset, False)
#     109   logits_test = getNN4Layer(tf_test_dataset, False)
#     110
#
# <ipython-input-5-6b16d44592fb> in getNN4Layer(dSet, use_dropout)
#      48   # get the NN models
#      49   def getNN4Layer(dSet, use_dropout):
# ---> 50     input_to_layer1 = tf.matmul(dSet, weights_layer1) + biases_layer1
#      51     hidden_layer1_output = tf.nn.relu(input_to_layer1)
#      52
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/tensorflow/python/ops/math_ops.pyc in matmul(a, b, transpose_a, transpose_b, a_is_sparse, b_is_sparse, name)
#     949                                    transpose_a=transpose_a,
#     950                                    transpose_b=transpose_b,
# --> 951                                    name=name)
#     952
#     953 sparse_matmul = gen_math_ops._sparse_mat_mul
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/tensorflow/python/ops/gen_math_ops.pyc in _mat_mul(a, b, transpose_a, transpose_b, name)
#     684   """
#     685   return _op_def_lib.apply_op("MatMul", a=a, b=b, transpose_a=transpose_a,
# --> 686                               transpose_b=transpose_b, name=name)
#     687
#     688
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/tensorflow/python/ops/op_def_library.pyc in apply_op(self, op_type_name, name, **keywords)
#     653         op = g.create_op(op_type_name, inputs, output_types, name=scope,
#     654                          input_types=input_types, attrs=attr_protos,
# --> 655                          op_def=op_def)
#     656         outputs = op.outputs
#     657         return _Restructure(ops.convert_n_to_tensor(outputs), output_structure)
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/tensorflow/python/framework/ops.pyc in create_op(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_shapes, compute_device)
#    2040                     original_op=self._default_original_op, op_def=op_def)
#    2041     if compute_shapes:
# -> 2042       set_shapes_for_outputs(ret)
#    2043     self._add_op(ret)
#    2044     self._record_op_seen_by_control_dependencies(ret)
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/tensorflow/python/framework/ops.pyc in set_shapes_for_outputs(op)
#    1526       raise RuntimeError("No shape function registered for standard op: %s"
#    1527                          % op.type)
# -> 1528   shapes = shape_func(op)
#    1529   if len(op.outputs) != len(shapes):
#    1530     raise RuntimeError(
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/tensorflow/python/ops/common_shapes.pyc in matmul_shape(op)
#      79 def matmul_shape(op):
#      80   """Shape function for a MatMul op."""
# ---> 81   a_shape = op.inputs[0].get_shape().with_rank(2)
#      82   transpose_a = op.get_attr("transpose_a")
#      83   b_shape = op.inputs[1].get_shape().with_rank(2)
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/tensorflow/python/framework/tensor_shape.pyc in with_rank(self, rank)
#     614       return self.merge_with(unknown_shape(ndims=rank))
#     615     except ValueError:
# --> 616       raise ValueError("Shape %s must have rank %d" % (self, rank))
#     617
#     618   def with_rank_at_least(self, rank):
#
# ValueError: Shape (10000, 28, 28, 1) must have rank 2

# %% [markdown]
# ##
